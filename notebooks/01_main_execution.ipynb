# %% [markdown]
# # BIOF4001 Data Collection Pipeline Code Submission
# Written by Mina (Hyun Soo) Seong
#
# This notebook contains the final execution entry-point for the BIOF4001 Data Collection Pipeline Code Submission, which standardizes and batch-processes the multimodal dataset (2‑lead ECG, 12‑lead ECG, and auscultation signals) into a consistent format per participant.

# %%
# %pip install -r "../requirements.txt"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os

# 1. Move up to Root Directory
if os.getcwd().endswith('notebooks'):
    os.chdir('..') 
print(f"Working Directory: {os.getcwd()}")
# Out:
# Working Directory: /Users/soonheekim/Desktop/FYP/Code_v01

# %%
# 2. Run Main
from main import main
main()
# Out:
# ...
# CARDIO MULTIMODAL PROCESSING PIPELINE
# ...
#
# --- 1. Building Manifest ---
# Found 5 patients: [4001, 4003, 4004, 4005, 4006]
# Excluded: [4002] (Missing Data)
# Processing Patients:   0%|          | 0/5 [00:00<?, ?it/s]
# ...
# Processing Patient 4001
# ...
#   [1/4] 2-Lead ECG from 4001-4006.sqlite3
# ⚠️ WARNING: Count Mismatch in 4001-4006.sqlite3!
#    Expected 6 patients ([4001, 4002, 4003, 4004, 4005, 4006])
#    Found 5 distinct recordings in DB.
#    Proceeding with index-based mapping assumption...
#       ✗ Error: invalid literal for int() with base 10: '4001_2lead'
#   [2/4] 12-Lead ECG from 4001.dcm
# ✓ Saved 12-lead plot to data/processed/4001/plots/12lead_grid.png
#       ✗ Error: invalid literal for int() with base 10: '4001_12lead_II'
#   [3/4] iPhone PCG from iData4001M.wav
# /Users/soonheekim/Desktop/FYP/Code_v01/src/loaders.py:219: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   fs, signal = wav.read(filepath)
# ...
